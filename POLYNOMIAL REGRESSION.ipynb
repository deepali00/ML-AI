# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#generating random values
x=np.linspace(0,10,500)
c=np.random.randn(500)
y=x**3+c*100+100
plt.scatter(x,y)

# %%
x.shape
# Out:
# (500,)

# %%
y.shape
# Out:
# (500,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lg=LinearRegression()

# %%
x1= x.reshape(-1,1)

# %%
x1.shape
# Out:
# (500, 1)

# %%
# for checking the dimension
x1.ndim
# Out:
# 2

# %%
lg.fit(x1,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=lg.predict(x1)

# %%
from sklearn.metrics import r2_score

# %%
score= r2_score(y,pred)

# %%
print(score)
# Out:
# 0.758463187756397

# %%
# since r2_score is not close to 1 which implies that our model is not working properly

# %%
plt.scatter(x,y)
plt.plot(x,pred,linewidth=4,color='green')

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly= PolynomialFeatures(degree=2)

# %%
poly_x= poly.fit_transform(x1)

# %%
poly_x.shape
# Out:
# (500, 3)

# %%
lg=LinearRegression()

# %%
lg.fit(poly_x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred= lg.predict(poly_x)

# %%
score= r2_score(y,pred)

# %%
print(score)
# Out:
# 0.8945578330652082

# %%
plt.scatter(x,y)
plt.plot(x,pred,linewidth=5,color='red')

# %%
# working on housing datasets

# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
boston= load_boston()

# %%
x= boston.data #features

# %%
y= boston.target #output

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=.2, random_state=10)

# %%
x_train
# Out:
# array([[8.87300e-02, 2.10000e+01, 5.64000e+00, ..., 1.68000e+01,
#         3.95560e+02, 1.34500e+01],
#        [1.35222e+01, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         1.31420e+02, 1.33300e+01],
#        [1.61282e+00, 0.00000e+00, 8.14000e+00, ..., 2.10000e+01,
#         2.48310e+02, 2.03400e+01],
#        ...,
#        [2.37857e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         3.70730e+02, 1.33400e+01],
#        [1.69020e-01, 0.00000e+00, 2.56500e+01, ..., 1.91000e+01,
#         3.85020e+02, 1.48100e+01],
#        [7.61620e-01, 2.00000e+01, 3.97000e+00, ..., 1.30000e+01,
#         3.92400e+02, 1.04500e+01]])

# %%
y_train
# Out:
# array([19.7, 23.1, 13.5, 21.2, 23.1, 13.6, 22.8, 18.2, 13.1, 23.2, 22.8,
#        25.1, 18.9, 10.9, 19.3, 17.4, 15.6, 20.6, 50. , 32.7, 21.8, 13.4,
#        16.6, 23.6, 11. , 23.8, 23.1, 33.2, 28.2,  8.5, 32.4, 29.6, 17.1,
#        24.2, 26.4, 33.2, 10.5,  8.8, 28. , 10.5, 15.4, 15.3, 10.4, 15.7,
#        43.1, 24.7, 21. , 19.4, 10.9, 21.7, 38.7, 19.2, 12. , 17.5, 23.9,
#         9.7, 15.4, 26.5, 10.8, 12.7, 18.4, 15.2, 29.8, 20. , 23.8, 14.6,
#        19.8, 10.2, 23.7, 18.7, 20.3, 50. , 25. , 14.8,  9.5, 33. , 19.4,
#        15.6, 20.2, 21.7, 24.7, 19.5,  7.2, 31.7, 22.4, 14.1, 21.4, 21.7,
#        23. , 20.3, 30.7, 35.1, 20.9, 27. , 10.2, 22.4, 23.3, 33.1, 28.7,
#        31.6, 22.2, 17.4, 16.1, 23. , 35.4, 22.9, 34.9, 19.5, 21. , 24.8,
#        30.5, 36.5, 21.5, 17.5, 19.4, 34.7, 19.6, 25. , 13.9, 13.3, 18.5,
#        12.3, 20. , 22. , 13.6, 14.9, 32. , 22.5, 23.9, 50. , 13.8, 20.1,
#        20.8, 18.8, 50. , 22.2, 26.2, 20.1, 13.8, 19.8, 17.8, 24.1, 19.4,
# ...

# %%
x_train.shape
# Out:
# (404, 13)

# %%
y_train.shape
# Out:
# (404,)

# %%
#option 1 to solve the prblm

# %%
lg= LinearRegression()

# %%
lg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
train_score= lg.score(x_train, y_train)
test_score= lg.score(x_test, y_test)

# %%
poly_test.shape
# Out:
# (102, 105)

# %%
train_score
# Out:
# 0.750121534530608

# %%
test_score
# Out:
# 0.670933983911564

# %%
# option2 to solve prblm

# %%
poly =PolynomialFeatures()

# %%
poly_train= poly.fit_transform(x_train)

# %%
poly_test= poly.fit_transform(x_test)

# %%
poly_train.shape
# Out:
# (404, 105)

# %%
lg= LinearRegression()

# %%
lg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
score_train = lg.score(poly_train,y_train)
score_test = lg.score(poly_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-0a56edff043c> in <module>
# ----> 1 score_train = lg.score(poly_train,y_train)
#       2 score_test = lg.score(poly_test,y_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     406         from .metrics import r2_score
#     407         from .metrics.regression import _check_reg_targets
# --> 408         y_pred = self.predict(X)
#     409         # XXX: Remove the check in 0.23
#     410         y_type, _, _, _ = _check_reg_targets(y, y_pred, None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# ...
